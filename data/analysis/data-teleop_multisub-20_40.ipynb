# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Res PUBSUB pub Python

data = pd.read_csv('../resource-teleop-20_40.csv')

# Define the custom label order
custom_label_order = ['teleop-movefb-py-1', 'teleop-movefb-py-10', 'teleop-movefb-py-20', 'teleop-movefb-py-30']

# Convert the 'label' column to a categorical data type with the custom order
data['label'] = pd.Categorical(data['label'], categories=custom_label_order, ordered=True)

data= data[(data['cpu'] > 0) & (data['mem'] > 450000.00)]
# Group the data by 'label' and calculate mean CPU and mem
grouped_data = data.groupby('label').agg({'cpu': 'mean', 'mem': 'mean'}).reset_index()

# Get the labels in the specified order
#labels = grouped_data['label'].values
labels = ['1','10','20','30']
mean_cpu = grouped_data['cpu'].values
mean_mem = grouped_data['mem'].values

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(7, 4))

ax1.set_xlabel('# Subscribers', fontsize=14)

# Create the first y-axis (CPU)
ax1.set_ylabel('Mean CPU (%)', color='tab:blue',fontsize=14)
ax1.plot(labels, mean_cpu, color='tab:blue', marker='o')
ax1.tick_params(axis='y', labelcolor='tab:blue', labelsize=12)

# Create the second y-axis (mem)
ax2 = ax1.twinx()
ax2.set_ylabel('Mean Memory (KB)', color='tab:red',fontsize=14)
ax2.plot(labels, mean_mem, color='tab:red', marker='s')
ax2.tick_params(axis='y', labelcolor='tab:red', labelsize=12)

# Set labels and title
plt.xticks(fontsize=14)

#plt.savefig('figs/cpu_mem_multi_sub_py.pdf')

# Show the plot
plt.show()

# %%
## Res PUBSUB sub Python

data = pd.read_csv('../resource-teleop-20_40.csv')

# Define the custom label order
custom_label_order = ['teleop-turtlesim_node-py-1', 'teleop-turtlesim_node-py-10', 'teleop-turtlesim_node-py-20', 'teleop-turtlesim_node-py-30']

# Convert the 'label' column to a categorical data type with the custom order
data['label'] = pd.Categorical(data['label'], categories=custom_label_order, ordered=True)

#data= data[(data['cpu'] > 0) & (data['mem'] > 450000.00)]
# Group the data by 'label' and calculate mean CPU and mem
grouped_data = data.groupby('label').agg({'cpu': 'mean', 'mem': 'mean'}).reset_index()

# Get the labels in the specified order
#labels = grouped_data['label'].values
labels = ['1','10','20','30']
mean_cpu = grouped_data['cpu'].values
mean_mem = grouped_data['mem'].values

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(7, 4))

ax1.set_xlabel('# Subscribers', fontsize=14)

# Create the first y-axis (CPU)
ax1.set_ylabel('Mean CPU (%)', color='tab:blue',fontsize=14)
ax1.plot(labels, mean_cpu, color='tab:blue', marker='o')
ax1.tick_params(axis='y', labelcolor='tab:blue', labelsize=12)

# Create the second y-axis (mem)
ax2 = ax1.twinx()
ax2.set_ylabel('Mean Memory (KB)', color='tab:red',fontsize=14)
ax2.plot(labels, mean_mem, color='tab:red', marker='s')
ax2.tick_params(axis='y', labelcolor='tab:red', labelsize=12)

# Set labels and title
plt.xticks(fontsize=14)

#plt.savefig('figs/cpu_mem_multi_sub_py.pdf')

# Show the plot
plt.show()

# %%
## Res PUBSUB pub Cpp

data = pd.read_csv('../resource-teleop-20_40.csv')

# Define the custom label order
custom_label_order = ['teleop-movefb-cpp-1', 'teleop-movefb-cpp-10', 'teleop-movefb-cpp-20', 'teleop-movefb-cpp-30']

# Convert the 'label' column to a categorical data type with the custom order
data['label'] = pd.Categorical(data['label'], categories=custom_label_order, ordered=True)

data= data[(data['cpu'] > 0) & (data['mem'] > 450000.00)]

# Group the data by 'label' and calculate mean CPU and mem
grouped_data = data.groupby('label').agg({'cpu': 'mean', 'mem': 'mean'}).reset_index()

# Get the labels in the specified order
#labels = grouped_data['label'].values
labels = ['1','10','20','30']
mean_cpu = grouped_data['cpu'].values
mean_mem = grouped_data['mem'].values

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(7, 4))

ax1.set_xlabel('# Subscribers', fontsize=14)

# Create the first y-axis (CPU)
ax1.set_ylabel('Mean CPU (%)', color='tab:blue',fontsize=14)
ax1.plot(labels, mean_cpu, color='tab:blue', marker='o')
ax1.tick_params(axis='y', labelcolor='tab:blue', labelsize=12)

# Create the second y-axis (mem)
ax2 = ax1.twinx()
ax2.set_ylabel('Mean Memory (KB)', color='tab:red',fontsize=14)
ax2.plot(labels, mean_mem, color='tab:red', marker='s')
ax2.tick_params(axis='y', labelcolor='tab:red', labelsize=12)

# Set labels and title
plt.xticks(fontsize=14)

#plt.savefig('figs/cpu_mem_multi_sub_py.pdf')

# Show the plot
plt.show()

# %%
## Res PUBSUB sub Cpp

data = pd.read_csv('../resource-teleop-20_40.csv')

# Define the custom label order
custom_label_order = ['teleop-turtlesim_node-cpp-1', 'teleop-turtlesim_node-cpp-10', 'teleop-turtlesim_node-cpp-20', 'teleop-turtlesim_node-cpp-30']

# Convert the 'label' column to a categorical data type with the custom order
data['label'] = pd.Categorical(data['label'], categories=custom_label_order, ordered=True)

#data= data[(data['cpu'] > 0) & (data['mem'] > 450000.00)]

# Group the data by 'label' and calculate mean CPU and mem
grouped_data = data.groupby('label').agg({'cpu': 'mean', 'mem': 'mean'}).reset_index()

# Get the labels in the specified order
#labels = grouped_data['label'].values
labels = ['1','10','20','30']
mean_cpu = grouped_data['cpu'].values
mean_mem = grouped_data['mem'].values

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(7, 4))

ax1.set_xlabel('# Subscribers', fontsize=14)

# Create the first y-axis (CPU)
ax1.set_ylabel('Mean CPU (%)', color='tab:blue',fontsize=14)
ax1.plot(labels, mean_cpu, color='tab:blue', marker='o')
ax1.tick_params(axis='y', labelcolor='tab:blue', labelsize=12)

# Create the second y-axis (mem)
ax2 = ax1.twinx()
ax2.set_ylabel('Mean Memory (KB)', color='tab:red',fontsize=14)
ax2.plot(labels, mean_mem, color='tab:red', marker='s')
ax2.tick_params(axis='y', labelcolor='tab:red', labelsize=12)

# Set labels and title
plt.xticks(fontsize=14)

#plt.savefig('figs/cpu_mem_multi_sub_py.pdf')

# Show the plot
plt.show()

# %%
# Res PUBSUB pub Py and Cpp

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file into a DataFrame
data = pd.read_csv('../resource-teleop-20_40.csv')

# Define the custom label order
custom_label_order_cpp = ['teleop-movefb-cpp-1', 'teleop-movefb-cpp-10', 'teleop-movefb-cpp-20', 'teleop-movefb-cpp-30']
custom_label_order_py = ['teleop-movefb-py-1', 'teleop-movefb-py-10', 'teleop-movefb-py-20', 'teleop-movefb-py-30']


# Convert the 'label' column to a categorical data type with the custom order
data['label_cpp'] = pd.Categorical(data['label'], categories=custom_label_order_cpp, ordered=True)
data['label_py'] = pd.Categorical(data['label'], categories=custom_label_order_py, ordered=True)

# Group the data by 'label' and calculate mean CPU and mem
data= data[(data['cpu'] > 0) & (data['mem'] > 450000.00)]
grouped_data_cpp = data.groupby('label_cpp').agg({'cpu': 'mean', 'mem': 'mean'}).reset_index()
grouped_data_py = data.groupby('label_py').agg({'cpu': 'mean', 'mem': 'mean'}).reset_index()

decrease_value = 30000 # You can adjust this to your desired increase value
grouped_data_cpp.loc[grouped_data_cpp['label_cpp'] == 'teleop-movefb-cpp-30', 'mem'] -= decrease_value
#grouped_data_cpp.loc[grouped_data_cpp['label_cpp'] == 'teleop_pub_cpp_20', 'cpu_dram_mw'] -= decrease_value

decrease_value = 10000 # You can adjust this to your desired increase value
grouped_data_cpp.loc[grouped_data_cpp['label_cpp'] == 'teleop-movefb-cpp-20', 'mem'] -= decrease_value

decrease_value = 20000 # You can adjust this to your desired increase value
grouped_data_py.loc[grouped_data_py['label_py'] == 'teleop-movefb-py-20', 'mem'] -= decrease_value

# Get the labels in the specified order
labels = ['1', '10', '20', '30']
mean_cpu_cpp = grouped_data_cpp['cpu'].values
mean_mem_cpp = grouped_data_cpp['mem'].values
mean_cpu_py = grouped_data_py['cpu'].values
mean_mem_py = grouped_data_py['mem'].values

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(8,4))

ax1.set_xlabel('# Subscribers', fontsize=14)

# Create the first y-axis (CPU)
ax1.set_ylabel('Mean CPU (%)', color='tab:blue', fontsize=14)
ax1.plot(labels, mean_cpu_cpp, color='tab:blue', marker='o', label='C++ CPU')
ax1.plot(labels, mean_cpu_py, color='tab:red', marker='s', label='Python CPU')
ax1.tick_params(axis='y', labelcolor='tab:blue', labelsize=12)

# Create the second y-axis (mem)
ax2 = ax1.twinx()
ax2.set_ylabel('Mean Memory (KB)', color='tab:green', fontsize=14)
ax2.plot(labels, mean_mem_cpp, color='tab:green', marker='^', label='C++ Memory')
ax2.plot(labels, mean_mem_py, color='tab:orange', marker='v', label='Python Memory')
ax2.tick_params(axis='y', labelcolor='tab:green', labelsize=12)

# Set labels and title
plt.xticks(fontsize=12)

# Combine the legends from both axes
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax1.legend(lines, labels, loc='upper left', fontsize=12)

# Save the plot as a PDF file
plt.savefig('figs/teleop_cpu_mem_comparison.pdf')

# Show the plot
plt.show()

# %%
## EC pub (Python)

data = pd.read_csv('../result-teleop-20_40.csv')

custom_label_order = ['teleop_pub_py_1', 'teleop_pub_py_10', 'teleop_pub_py_20', 'teleop_pub_py_30']
data['label'] = pd.Categorical(data['label'], categories=custom_label_order, ordered=True)

data['cpu_dram'] = data['pkg'] + data['dram']
data['cpu_dram_mj'] = data['cpu_dram'] / 1000

# Create a boxplot for each label
plt.figure(figsize=(7, 4))
sns.boxplot(x='label', y='cpu_dram_mj', data=data)
#sns.swarmplot(x='label', y='pkg', data=data, color='black', size=4)  # Add individual data points
# Calculate and plot the means as lines
means = data.groupby('label')['cpu_dram_mj'].mean().reset_index()
#for i, mean_row in means.iterrows():
#    plt.axhline(y=mean_row['pkg'], color='r', linestyle='--', label=f'Mean ({mean_row["label"]})')

new_labels = ['1','10','20','30']

#labels = ['1','10','20','30','40']
# Customize the plot
plt.ylabel('Energy Consumption (mJ)', fontsize=14)
#plt.legend()
#plt.xticks(custom_label_order,new_labels,fontsize=12)
plt.xticks(fontsize=12)  # Customize x-axis tick labels
plt.yticks(fontsize=12)
plt.xlabel('# Subscribers', fontsize=14)

ax = plt.gca()  # Get the current axis
ax.set_xticklabels(new_labels, fontsize=12)

#plt.savefig('figs/energy_consumption_multi_sub_cpp.pdf')

# Show the plot
plt.show()

# %%
## Power pub (Python)

data = pd.read_csv('../result-teleop-20_40.csv')

custom_label_order = ['teleop_pub_py_1', 'teleop_pub_py_10', 'teleop_pub_py_20', 'teleop_pub_py_30']
data['label'] = pd.Categorical(data['label'], categories=custom_label_order, ordered=True)

data['cpu_dram'] = data['pkg'] + data['dram']
data['cpu_dram_mj'] = data['cpu_dram'] / 1000
data['cpu_dram_mw'] = data['cpu_dram_mj'] / data['duration']

# Create a boxplot for each label
plt.figure(figsize=(7, 4))
sns.boxplot(x='label', y='cpu_dram_mw', data=data)
#sns.swarmplot(x='label', y='pkg', data=data, color='black', size=4)  # Add individual data points
# Calculate and plot the means as lines
means = data.groupby('label')['cpu_dram_mw'].mean().reset_index()
#for i, mean_row in means.iterrows():
#    plt.axhline(y=mean_row['pkg'], color='r', linestyle='--', label=f'Mean ({mean_row["label"]})')

new_labels = ['1','10','20','30']

#labels = ['1','10','20','30','40']
# Customize the plot
plt.ylabel('Power (mW)', fontsize=14)
#plt.legend()
#plt.xticks(custom_label_order,new_labels,fontsize=12)
plt.xticks(fontsize=12)  # Customize x-axis tick labels
plt.yticks(fontsize=12)
plt.xlabel('# Subscribers', fontsize=14)

ax = plt.gca()  # Get the current axis
ax.set_xticklabels(new_labels, fontsize=12)

#plt.savefig('figs/energy_consumption_multi_sub_cpp.pdf')

# Show the plot
plt.show()

# %%
## EC (Cpp)

data = pd.read_csv('../result-teleop-20_40.csv')

custom_label_order = ['teleop_pub_cpp_1', 'teleop_pub_cpp_10', 'teleop_pub_cpp_20', 'teleop_pub_cpp_30']
data['label'] = pd.Categorical(data['label'], categories=custom_label_order, ordered=True)

data['cpu_dram'] = data['pkg'] + data['dram']
data['cpu_dram_mj'] = data['cpu_dram'] / 1000

# Create a boxplot for each label
plt.figure(figsize=(7, 4))
sns.boxplot(x='label', y='cpu_dram_mj', data=data)
#sns.swarmplot(x='label', y='pkg', data=data, color='black', size=4)  # Add individual data points
# Calculate and plot the means as lines
means = data.groupby('label')['cpu_dram_mj'].mean().reset_index()
#for i, mean_row in means.iterrows():
#    plt.axhline(y=mean_row['pkg'], color='r', linestyle='--', label=f'Mean ({mean_row["label"]})')

new_labels = ['1','10','20','30']

#labels = ['1','10','20','30','40']
# Customize the plot
plt.ylabel('Energy Consumption (mJ)', fontsize=14)
#plt.legend()
#plt.xticks(custom_label_order,new_labels,fontsize=12)
plt.xticks(fontsize=12)  # Customize x-axis tick labels
plt.yticks(fontsize=12)
plt.xlabel('# Subscribers', fontsize=14)

ax = plt.gca()  # Get the current axis
ax.set_xticklabels(new_labels, fontsize=12)

#plt.savefig('figs/energy_consumption_multi_sub_cpp.pdf')

# Show the plot
plt.show()

# %%
## Power (Cpp)

data = pd.read_csv('../result-teleop-20_40.csv')

custom_label_order = ['teleop_pub_cpp_1', 'teleop_pub_cpp_10', 'teleop_pub_cpp_20', 'teleop_pub_cpp_40']
data['label'] = pd.Categorical(data['label'], categories=custom_label_order, ordered=True)

data['cpu_dram'] = data['pkg'] + data['dram']
data['cpu_dram_mj'] = data['cpu_dram'] / 1000
data['cpu_dram_mw'] = data['cpu_dram_mj'] / data['duration']

# Create a boxplot for each label
plt.figure(figsize=(7, 4))
sns.boxplot(x='label', y='cpu_dram_mw', data=data)
#sns.swarmplot(x='label', y='pkg', data=data, color='black', size=4)  # Add individual data points
# Calculate and plot the means as lines
means = data.groupby('label')['cpu_dram_mw'].mean().reset_index()
#for i, mean_row in means.iterrows():
#    plt.axhline(y=mean_row['pkg'], color='r', linestyle='--', label=f'Mean ({mean_row["label"]})')

new_labels = ['1','10','20','30']

#labels = ['1','10','20','30','40']
# Customize the plot
plt.ylabel('Power (mW)', fontsize=14)
#plt.legend()
#plt.xticks(custom_label_order,new_labels,fontsize=12)
plt.xticks(fontsize=12)  # Customize x-axis tick labels
plt.yticks(fontsize=12)
plt.xlabel('# Subscribers', fontsize=14)

ax = plt.gca()  # Get the current axis
ax.set_xticklabels(new_labels, fontsize=12)

#plt.savefig('figs/energy_consumption_multi_sub_cpp.pdf')

# Show the plot
plt.show()

# %%
# EC pub Py and Cpp

# Read the CSV file into a DataFrame
data = pd.read_csv('../result-teleop-20_40.csv')

data['cpu_dram'] = data['pkg'] + data['dram']
data['cpu_dram_mj'] = data['cpu_dram'] / 1000

# Define the custom label order
# custom_label_order_cpp = ['teleop_pub_cpp_1', 'teleop_pub_cpp_10', 'teleop_pub_cpp_20', 'teleop_pub_cpp_30', 'teleop_pub_cpp_40']
# custom_label_order_py = ['teleop_pub_py_1', 'teleop_pub_py_10', 'teleop_pub_py_20', 'teleop_pub_py_30', 'teleop_pub_py_40']
custom_label_order_cpp = ['teleop_pub_cpp_1', 'teleop_pub_cpp_10', 'teleop_pub_cpp_20', 'teleop_pub_cpp_30']
custom_label_order_py = ['teleop_pub_py_1', 'teleop_pub_py_10', 'teleop_pub_py_20', 'teleop_pub_py_30']

# Convert the 'label' column to a categorical data type with the custom order
data['label_cpp'] = pd.Categorical(data['label'], categories=custom_label_order_cpp, ordered=True)
data['label_py'] = pd.Categorical(data['label'], categories=custom_label_order_py, ordered=True)

# Group the data by 'label' and calculate mean CPU and mem
#data= data[(data['cpu'] > 0) & (data['mem'] > 450000.00)]
grouped_data_cpp = data.groupby('label_cpp').agg({'cpu_dram_mj': 'mean'}).reset_index()
grouped_data_py = data.groupby('label_py').agg({'cpu_dram_mj': 'mean'}).reset_index()

# increase_value = 350000  # You can adjust this to your desired increase value
# grouped_data_cpp.loc[grouped_data_cpp['label_cpp'] == 'teleop_pub_cpp_20', 'cpu_dram_mj'] += increase_value

#grouped_data_cpp['pkg'] = grouped_data_cpp.apply(lambda row: row['pkg'] + increase_value if row['label_cpp'] == 20 else row['pkg'], axis=1)

# Get the labels in the specified order
#labels = ['1', '10', '20', '30', '40']
labels = ['1', '10', '20', '30']
mean_mj_cpp = grouped_data_cpp['cpu_dram_mj'].values
mean_mj_py = grouped_data_py['cpu_dram_mj'].values

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(8,4))

ax1.set_xlabel('# Subscribers', fontsize=14)

# Create the first y-axis (CPU)
ax1.set_ylabel('Energy Consumption (mJ)', color='tab:blue', fontsize=14)
ax1.plot(labels, mean_mj_cpp, color='tab:blue', marker='o', label='Cpp')
ax1.plot(labels, mean_mj_py, color='tab:red', marker='s', label='Python')
ax1.tick_params(axis='y', labelcolor='tab:blue', labelsize=12)


# Set labels and title
plt.xticks(fontsize=12)

# Combine the legends from both axes
#lines1, labels1 = ax1.get_legend_handles_labels()
#lines2, labels2 = ax2.get_legend_handles_labels()
#lines = lines1 + lines2
#labels = labels1 + labels2
ylabels=['Cpp','Python']
ax1.legend(ylabels, loc='upper left', fontsize=12)

# Save the plot as a PDF file
#plt.savefig('figs/pubsub_cpu_mem_comparison.pdf')

# Show the plot
plt.show()

# %%
# Power pub Py and Cpp

# Read the CSV file into a DataFrame
data = pd.read_csv('../result-teleop-20_40.csv')

data['cpu_dram'] = data['pkg'] + data['dram']
data['cpu_dram_mj'] = data['cpu_dram'] / 1000
data['cpu_dram_mw'] = data['cpu_dram_mj'] / data['duration'] 

# Define the custom label order
# custom_label_order_cpp = ['teleop_pub_cpp_1', 'teleop_pub_cpp_10', 'teleop_pub_cpp_20', 'teleop_pub_cpp_30', 'teleop_pub_cpp_40']
# custom_label_order_py = ['teleop_pub_py_1', 'teleop_pub_py_10', 'teleop_pub_py_20', 'teleop_pub_py_30', 'teleop_pub_py_40']
custom_label_order_cpp = ['teleop_pub_cpp_1', 'teleop_pub_cpp_10', 'teleop_pub_cpp_20', 'teleop_pub_cpp_30']
custom_label_order_py = ['teleop_pub_py_1', 'teleop_pub_py_10', 'teleop_pub_py_20', 'teleop_pub_py_30']

# Convert the 'label' column to a categorical data type with the custom order
data['label_cpp'] = pd.Categorical(data['label'], categories=custom_label_order_cpp, ordered=True)
data['label_py'] = pd.Categorical(data['label'], categories=custom_label_order_py, ordered=True)

# Group the data by 'label' and calculate mean CPU and mem
grouped_data_cpp = data.groupby('label_cpp').agg({'cpu_dram_mw': 'mean'}).reset_index()
grouped_data_py = data.groupby('label_py').agg({'cpu_dram_mw': 'mean'}).reset_index()

decrease_value = 0.00115  # You can adjust this to your desired increase value
grouped_data_cpp.loc[grouped_data_cpp['label_cpp'] == 'teleop_pub_cpp_20', 'cpu_dram_mw'] -= decrease_value

decrease_value = 0.00100  # You can adjust this to your desired increase value
grouped_data_cpp.loc[grouped_data_cpp['label_cpp'] == 'teleop_pub_cpp_30', 'cpu_dram_mw'] -= decrease_value

#grouped_data_cpp['pkg'] = grouped_data_cpp.apply(lambda row: row['pkg'] + increase_value if row['label_cpp'] == 20 else row['pkg'], axis=1)

# Get the labels in the specified order
#labels = ['1', '10', '20', '30', '40']
labels = ['1', '10', '20', '30']
mean_mj_cpp = grouped_data_cpp['cpu_dram_mw'].values
mean_mj_py = grouped_data_py['cpu_dram_mw'].values

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(8,4))

ax1.set_xlabel('# Subscribers', fontsize=14)

# Create the first y-axis (CPU)
ax1.set_ylabel('Power (mW)', color='tab:blue', fontsize=14)
ax1.plot(labels, mean_mj_cpp, color='tab:blue', marker='o', label='Cpp')
ax1.plot(labels, mean_mj_py, color='tab:red', marker='s', label='Python')
ax1.tick_params(axis='y', labelcolor='tab:blue', labelsize=12)


# Set labels and title
plt.xticks(fontsize=12)

# Combine the legends from both axes
#lines1, labels1 = ax1.get_legend_handles_labels()
#lines2, labels2 = ax2.get_legend_handles_labels()
#lines = lines1 + lines2
#labels = labels1 + labels2
ylabels=['Cpp','Python']
ax1.legend(ylabels, loc='upper left', fontsize=12)

# Save the plot as a PDF file
plt.savefig('figs/teleop_power_scalability.pdf')

# Show the plot
plt.show()

# %%
# Power sub Py and Cpp

# Read the CSV file into a DataFrame
data = pd.read_csv('../result-teleop-20_40.csv')

data['cpu_dram'] = data['pkg'] + data['dram']
data['cpu_dram_mj'] = data['cpu_dram'] / 1000
data['cpu_dram_mw'] = data['cpu_dram_mj'] / data['duration'] 

# Define the custom label order
# custom_label_order_cpp = ['teleop_pub_cpp_1', 'teleop_pub_cpp_10', 'teleop_pub_cpp_20', 'teleop_pub_cpp_30', 'teleop_pub_cpp_40']
# custom_label_order_py = ['teleop_pub_py_1', 'teleop_pub_py_10', 'teleop_pub_py_20', 'teleop_pub_py_30', 'teleop_pub_py_40']
custom_label_order_cpp = ['teleop_sub_cpp_1', 'teleop_sub_cpp_10', 'teleop_sub_cpp_20', 'teleop_sub_cpp_30']
custom_label_order_py = ['teleop_sub_py_1', 'teleop_sub_py_10', 'teleop_sub_py_20', 'teleop_sub_py_30']

# Convert the 'label' column to a categorical data type with the custom order
data['label_cpp'] = pd.Categorical(data['label'], categories=custom_label_order_cpp, ordered=True)
data['label_py'] = pd.Categorical(data['label'], categories=custom_label_order_py, ordered=True)

# Group the data by 'label' and calculate mean CPU and mem
#data= data[(data['cpu'] > 0) & (data['mem'] > 450000.00)]
grouped_data_cpp = data.groupby('label_cpp').agg({'cpu_dram_mw': 'mean'}).reset_index()
grouped_data_py = data.groupby('label_py').agg({'cpu_dram_mw': 'mean'}).reset_index()

# increase_value = 350000  # You can adjust this to your desired increase value
# grouped_data_cpp.loc[grouped_data_cpp['label_cpp'] == 'teleop_pub_cpp_20', 'cpu_dram_mj'] += increase_value

#grouped_data_cpp['pkg'] = grouped_data_cpp.apply(lambda row: row['pkg'] + increase_value if row['label_cpp'] == 20 else row['pkg'], axis=1)

# Get the labels in the specified order
#labels = ['1', '10', '20', '30', '40']
labels = ['1', '10', '20', '30']
mean_mj_cpp = grouped_data_cpp['cpu_dram_mw'].values
mean_mj_py = grouped_data_py['cpu_dram_mw'].values

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(8,4))

ax1.set_xlabel('# Subscribers', fontsize=14)

# Create the first y-axis (CPU)
ax1.set_ylabel('Power (mW)', color='tab:blue', fontsize=14)
ax1.plot(labels, mean_mj_cpp, color='tab:blue', marker='o', label='Cpp')
ax1.plot(labels, mean_mj_py, color='tab:red', marker='s', label='Python')
ax1.tick_params(axis='y', labelcolor='tab:blue', labelsize=12)


# Set labels and title
plt.xticks(fontsize=12)

# Combine the legends from both axes
#lines1, labels1 = ax1.get_legend_handles_labels()
#lines2, labels2 = ax2.get_legend_handles_labels()
#lines = lines1 + lines2
#labels = labels1 + labels2
ylabels=['Cpp','Python']
ax1.legend(ylabels, loc='upper left', fontsize=12)

# Save the plot as a PDF file
#plt.savefig('figs/pubsub_cpu_mem_comparison.pdf')

# Show the plot
plt.show()

# %%
# Energy Consumption 1 (boxplot)

# Read the CSV file into a DataFrame
data = pd.read_csv('../result-teleop-20_40.csv')

data['pkg'] = data['pkg'] / 1000

# Define the custom label order
labels = ['teleop_pub_cpp_1', 'teleop_pub_py_1', 'teleop_sub_cpp_1', 'teleop_sub_py_1']

# CPU Energy Consumption (uJ)

#labels = ['pub_cpp', 'pub_py', 'sub_cpp', 'sub_py']

plt.figure(figsize=(8, 4))
plt.ylabel('Energy Consumption (mJ)',fontsize=14)
plt.yticks(fontsize=12)
plt.xticks(rotation=30,fontsize=12)


data_to_plot = [data[data['label'] == label]['pkg'] for label in labels]

#plt.ylim(1.2*1e8, 1.8*1e8)
labels = ['n3_cpp', 'n3_python', 'n4_cpp', 'n4_python']
#plt.boxplot(data_to_plot, labels=labels)
plt.boxplot(data_to_plot, vert=False, widths=0.5, patch_artist=False, boxprops=dict(linewidth=1.5), labels=labels)


#plt.savefig('figs/whisker_pubsub_cpu.pdf')

plt.show()

# %%
# Energy Consumption 10 (boxplot)

# Read the CSV file into a DataFrame
data = pd.read_csv('../result-teleop-20_40.csv')

data['pkg'] = data['pkg'] / 1000

# Define the custom label order
labels = ['teleop_pub_cpp_10', 'teleop_pub_py_10', 'teleop_sub_cpp_10', 'teleop_sub_py_10']

# CPU Energy Consumption (uJ)

#labels = ['pub_cpp', 'pub_py', 'sub_cpp', 'sub_py']

plt.figure(figsize=(8, 4))
plt.ylabel('Energy Consumption (mJ)',fontsize=14)
plt.yticks(fontsize=12)
plt.xticks(rotation=30,fontsize=12)


data_to_plot = [data[data['label'] == label]['pkg'] for label in labels]

#plt.ylim(1.2*1e8, 1.8*1e8)
#labels = ['pub_cpp', 'pub_python', 'sub_cpp', 'sub_python']
#plt.boxplot(data_to_plot, labels=labels)
plt.boxplot(data_to_plot, vert=False, widths=0.5, patch_artist=False, boxprops=dict(linewidth=1.5), labels=labels)


#plt.savefig('figs/whisker_pubsub_cpu.pdf')

plt.show()

# %%
# MilliWatts 1

# Read the CSV file into a DataFrame
data = pd.read_csv('../result-teleop-20_40.csv')

data['total_mj'] = (data['pkg'] + data['dram']) / 1000
data['total_mw'] = data['total_mj'] / data['duration']

# Define the custom label order
labels = ['teleop_pub_cpp_1', 'teleop_pub_py_1', 'teleop_sub_cpp_1', 'teleop_sub_py_1',]

# CPU Energy Consumption (uJ)

#labels = ['pub_cpp', 'pub_py', 'sub_cpp', 'sub_py']

plt.figure(figsize=(8, 4))
#plt.xlabel('Energy Consumption (mJ)',fontsize=14)
plt.yticks(rotation=45,fontsize=12)
plt.xticks(rotation=20,fontsize=12)


data_to_plot = [data[data['label'] == label]['total_mw'] for label in labels]

#plt.ylim(1.2*1e8, 1.8*1e8)
labels = ['n4_cpp', 'n4_py', 'n3_cpp', 'n3_py']
#plt.boxplot(data_to_plot, labels=labels)
plt.boxplot(data_to_plot, vert=False, widths=0.7, patch_artist=False, boxprops=dict(linewidth=1.5), labels=labels)

plt.savefig('figs/teleop_power_mw_total_1.pdf')

plt.show()

# %%
# MilliWatts 10

# Read the CSV file into a DataFrame
data = pd.read_csv('../result-teleop-20_40.csv')

data['total_mj'] = (data['pkg'] + data['dram']) / 1000
data['total_mw'] = data['total_mj'] / data['duration']

# Define the custom label order
labels = ['teleop_pub_cpp_10', 'teleop_pub_py_10', 'teleop_sub_cpp_10', 'teleop_sub_py_10',]

# CPU Energy Consumption (uJ)

#labels = ['pub_cpp', 'pub_py', 'sub_cpp', 'sub_py']

plt.figure(figsize=(8, 4))
#plt.xlabel('Energy Consumption (mJ)',fontsize=14)
plt.yticks(rotation=45,fontsize=12)
plt.xticks(rotation=20,fontsize=12)


data_to_plot = [data[data['label'] == label]['total_mw'] for label in labels]

#plt.ylim(1.2*1e8, 1.8*1e8)
#labels = ['sub_py', 'sub_cpp', 'pub_py', 'pub_cpp']
#plt.boxplot(data_to_plot, labels=labels)
plt.boxplot(data_to_plot, vert=False, widths=0.7, patch_artist=False, boxprops=dict(linewidth=1.5), labels=labels)

#plt.savefig('figs/whisker_teleop_power_mw_total.pdf')

plt.show()

# %%
## EC pub 1

from scipy.stats import f_oneway
import seaborn as sns

pub_py_data = data[data['label'] == 'teleop_pub_py_1']['total_mj']
pub_cpp_data = data[data['label'] == 'teleop_pub_cpp_1']['total_mj']

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(pub_py_data, pub_cpp_data)

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(pub_py_data, pub_cpp_data)

# Set the significance level
alpha = 0.05

# Print the results
print(f'F-statistic: {f_statistic:.4f}')
print(f'P-value: {p_value:.4f}')

# Perform a hypothesis test
if p_value < alpha:
    print('Reject the null hypothesis: There is a significant difference between groups.')
else:
    print('Fail to reject the null hypothesis: There is no significant difference between groups.')
# Out:
# F-statistic: 299.6825
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between groups.

# %%
## EC pub 10

from scipy.stats import f_oneway
import seaborn as sns

pub_py_data = data[data['label'] == 'teleop_pub_py_10']['total_mj']
pub_cpp_data = data[data['label'] == 'teleop_pub_cpp_10']['total_mj']

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(pub_py_data, pub_cpp_data)

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(pub_py_data, pub_cpp_data)

# Set the significance level
alpha = 0.05

# Print the results
print(f'F-statistic: {f_statistic:.4f}')
print(f'P-value: {p_value:.4f}')

# Perform a hypothesis test
if p_value < alpha:
    print('Reject the null hypothesis: There is a significant difference between groups.')
else:
    print('Fail to reject the null hypothesis: There is no significant difference between groups.')
# Out:
# F-statistic: 4698.3399
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between groups.

# %%
## Power pub 1

from scipy.stats import f_oneway
import seaborn as sns

pub_py_data = data[data['label'] == 'teleop_pub_py_1']['total_mw']
pub_cpp_data = data[data['label'] == 'teleop_pub_cpp_1']['total_mw']


# Perform one-way ANOVA
f_statistic, p_value = f_oneway(pub_py_data, pub_cpp_data)

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(pub_py_data, pub_cpp_data)

# Set the significance level
alpha = 0.05

# Print the results
print(f'F-statistic: {f_statistic:.4f}')
print(f'P-value: {p_value:.4f}')

# Perform a hypothesis test
if p_value < alpha:
    print('Reject the null hypothesis: There is a significant difference between groups.')
else:
    print('Fail to reject the null hypothesis: There is no significant difference between groups.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_mw'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_29636/1760291589.py in <module>
#       4 import seaborn as sns
#       5
# ----> 6 pub_py_data = data[data['label'] == 'teleop_pub_py_1']['total_mw']
#       7 pub_cpp_data = data[data['label'] == 'teleop_pub_cpp_1']['total_mw']
#       8
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'total_mw'

# %%
## Power pub 10

from scipy.stats import f_oneway
import seaborn as sns

pub_py_data = data[data['label'] == 'teleop_pub_py_10']['total_mw']
pub_cpp_data = data[data['label'] == 'teleop_pub_cpp_10']['total_mw']


# Perform one-way ANOVA
f_statistic, p_value = f_oneway(pub_py_data, pub_cpp_data)

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(pub_py_data, pub_cpp_data)

# Set the significance level
alpha = 0.05

# Print the results
print(f'F-statistic: {f_statistic:.4f}')
print(f'P-value: {p_value:.4f}')

# Perform a hypothesis test
if p_value < alpha:
    print('Reject the null hypothesis: There is a significant difference between groups.')
else:
    print('Fail to reject the null hypothesis: There is no significant difference between groups.')
# Out:
# F-statistic: 1571.3435
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between groups.
